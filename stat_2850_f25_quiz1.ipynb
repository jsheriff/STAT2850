# %% [markdown]
# # STAT 2580 - Introduction to Data Science
# # Quiz 1
#
# -------
# ### Instructions:
# - Answer **all** questions in the spaces provided.
# - Do **not** delete or modify question text.
# - You may add code cells or markdown cells as necessary
# - Use **R** for all coding tasks.
# - Show your work and include brief explanations when asked.
# - Quiz is open book.
# - You must complete the quiz on your own.

# %%
### Run this cell before continuing. 
library(repr)
library(tidyverse)
library(palmerpenguins)
options(repr.matrix.max.rows = 6) #limits output of dataframes to 6 rows

# %% [markdown]
# **Question 1**
# <br> {points: 1}
#
# Choose the correct code from below to load the  `readr` library:
#
# A. readr
#
# B. read_csv("readr”)
#
# C. library(readr)
#
# D. install.packages("readr")
#
# E. load(readr)

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 2**
# <br> {points: 1}
#
# Consider the following dataset which shows information for four variables: country, year, population, and number of documented cases of TB (tuberculosis).
#
# Is this dataset tidy? Yes or No?

# %%
#> # A tibble: 12 × 4
#>   country      year type           count
#>   <chr>       <dbl> <chr>          <dbl>
#> 1 Afghanistan  1999 cases            745
#> 2 Afghanistan  1999 population  19987071
#> 3 Afghanistan  2000 cases           2666
#> 4 Afghanistan  2000 population  20595360
#> 5 Brazil       1999 cases          37737
#> 6 Brazil       1999 population 172006362
#> # ℹ 6 more rows

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 3**
# <br> {points: 3}
#
# Does it matter what order you use the functions `filter()` and `arrange()` if you’re using both? Why/why not? Think about the results and how much work the functions would have to do.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 4**
# <br> {points: 3}
#
# If the first 10 lines of a data file that you want to read into R looks like this:
#
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:13px 10px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:13px 10px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg"><thead>
#   <tr>
#     <th class="tg-0lax" colspan="6"></th>
#   </tr></thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax" colspan="6">Data collected in 2022</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax" colspan="6">Copyright 2022</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax" colspan="6">Lethbridge, AB</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">GP</td>
#     <td class="tg-0lax">GF</td>
#     <td class="tg-0lax">GA</td>
#     <td class="tg-0lax">PPG</td>
#     <td class="tg-0lax">SHG</td>
#     <td class="tg-0lax">PIM</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">8</td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">4</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">2</td>
#     <td class="tg-0lax">3</td>
#     <td class="tg-0lax">2</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">6</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">2</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">8</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">7</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">2</td>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">4</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">4</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">6</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">3</td>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">0</td>
#     <td class="tg-0lax">2</td>
#   </tr>
# </tbody></table>
#
#
# Fill in the missing pieces to the code below so that you could successfully read it into R (assume the `tidyverse` library has already been loaded):
#
# Please do not include any spaces in any answer for this question.
#
# `game_data <- read_...("game.tsv", ... = ...)`

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 5**
# <br> {points: 1}
#
# Suppose you are working in a notebook in the directory `/home/jupyter/stat2850/student/materials/`.
#
# You want to load a dataset with the absolute path
# `/home/jupyter/stat2850/student/materials/data/bike_share.csv`
#
# Which of the following will load the data using a relative path?
#
#
# A. read_csv("/data/bike_share.csv”)
#
# B. read_csv("data/bike_share.csv”)
#
# C. read_csv("/home/jupyter/stat2850/student/materials/data/bike_share.cs”)
#
# D. read_csv("bike_share.csv")

# %% [markdown]
# ### Palmer Penguins Data
#
# The `penguins` dataset has been loaded as part of the `palmerpenguins` package.
#
# `penguins` dataset
#
# **Description**
# Includes measurements for penguin species, island in Palmer Archipelago, size (flipper length, body mass, bill dimensions), and sex. This is a subset of penguins_raw.
#
# **Format**
# - `species`: a factor denoting penguin species (Adélie, Chinstrap and Gentoo)
# - `island`: a factor denoting island in Palmer Archipelago, Antarctica (Biscoe, Dream or Torgersen)
# - `bill_length_mm`: a number denoting bill length (millimeters)
# - `bill_depth_mm`: a number denoting bill depth (millimeters)
# - `flipper_length_mm`: an integer denoting flipper length (millimeters)
# - `body_mass_g`: an integer denoting body mass (grams)
# - `sex`: a factor denoting penguin sex (female, male)
# - `year`: an integer denoting the study year (2007, 2008, or 2009)

# %% [markdown]
# **Question 6**
# <br> {points: 2}
#
# How many rows are in `penguins`. How many columns are in `penguins`?

# %%
# your code here

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 7**
# <br> {points: 3}
#
# Given the `penguins` dataset, where `body_mass_g` is in grams, create a new column called `body_mass_kg` where body mass is in kilograms.
#
# *Recall: There are 1000 grams in a kilogram*

# %%
# your code here

# %% [markdown]
# **Question 8**
# <br> {points: 3}
#
# For the `penguins` dataset find all penguins that meet **all** of the following conditions:
#  - Are located on Biscoe island orTorgersen island
#  - Are male
#  - Have body mass of at least 6000g

# %%
# your code here

# %% [markdown]
# ### Fuel economy data
#
# The `mpg` dataset has been loaded as part of the `ggplot2` package.. It contains fuel economy data from 1999 to 2008 for 38 popular models of cars.
#
# **Description**
# This dataset contains a subset of the fuel economy data that the EPA makes available on https://fueleconomy.gov/. It contains only models which had a new release every year between 1999 and 2008 - this was used as a proxy for the popularity of the car.
#
# `mpg` dataset
#
# **Format**
# - `manufacturer`: manufacturer name
# - `model`: model name
# - `displ`: engine displacement (size), in litres
# - `year`: year of manufacture
# - `cyl`: number of cylinders
# - `trans` type of transmission
# - `drv`: the type of drive train, where f = front-wheel drive, r = rear wheel drive, 4 = 4wd
# - `cty`: city miles per gallon
# - `hwy`: highway miles per gallon
# - `fl`: fuel type
# - `class`: "type" of car

# %% [markdown]
# **Question 9**
# <br> {points: 3}
#
# Which variables in `mpg` are categorical?

# %%
# your code here

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 10**
# <br> {points: 3}
#
# Make a scatterplot of `hwy` vs. `displ` and colour the points by `drv`. Be sure to include meaningful labels.

# %%
# your code here

# %% [markdown]
# **Question 11**
# <br> {points: 4}
#
# What does the scatterplot say about the general relationship between fuel economy, `hwy`, and engine size, `displ`. What, if anything, does adding colouring by drive train, `drv`, reveal about the relationship between these two variables?

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 12**
# <br> {points: 4}
#
# Use the `arrange` function to sort `mpg` to find the vehicle with the best (largest) miles per gallon in the city, `cty`. Identify the manufacturer, model, year, and city mpg for the best vehicle.

# %%
# your code here

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 13**
# <br> {points: 4}
#
# For the `mpg` dataset we wish to compare average city miles per gallon, `cty` for compact cars, `class` is `compact`, and pickup trucks, `class` is `pickup`:
#  - Calculate the average, or mean, city miles per gallon, `cty`, for `compact` cars
#  - Calculate the average, or mean, city miles per gallon, `cty`, for `pickup` trucks
#  - Calculate the difference between the two

# %%
# your code here

# %% [markdown]
# ##### Answer:

# %% [markdown]
# ##### When you have completed your work <br><br> - File > Save and Export Notebook As > PDF, or <br> - File > Print > Save as PDF <br> - Submit your pdf through Crowdmark

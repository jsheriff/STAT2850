# %% [markdown]
# # STAT 2580 - Introduction to Data Science
# # Quiz 2
#
# -------
# ### Instructions:
# - Answer **all** questions in the spaces provided.
# - Do **not** delete or modify question text.
# - You may add code cells or markdown cells as necessary
# - Use **R** as necessary.
# - Show your work where possible and include brief explanations when asked.
# - Quiz is open book.
# - You must complete the quiz on your own.

# %%
### Run this cell before continuing. 
library(repr)
library(tidyverse)
library(tidymodels)
library(palmerpenguins)
options(repr.matrix.max.rows = 6) #limits output of dataframes to 6 rows

# %% [markdown]
# **Question 1**
# <br> {points: 1}
#
# Which of the following problems could be solved using classification?
#
# A.  An insurance company wants to predict how much money they will pay to a person based on that person's age and location.
# B.  A marketing company is interested in analyzing patterns in user spending habits.
# C.  A professor is interested in finding what variables, such as average time spent studying and number of classes attended, influence the final grades of their students.
# D.  A scientist who researches birds wants to determine whether an egg will hatch a male or female bird based on characteristics of the egg.
# E.  None of the options above are problems that could be solved using classification.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 2**
# <br> {points: 1}
#
# Suppose a KNN classifier gets 100% accuracy on training data, but it has been found that the model is not accurate at all when predicting for new data. Which of the following things might have gone wrong?
#
# A. The model is underfitting
# B. The model is overfitting
# C. The model is fitting the data well
# D. None of the above

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 3**
# <br> {points: 2}
#
# Consider the following KNN regression, where the response variable is in thousands of dollars.
# ![](img/knn_final_model.png)
#
# What would happen to the RMSPE and the model if the response variable was in dollars instead of thousands of dollars. (i.e.,the response range would become 0 to 300,000 instead of 0 to 300).
#
# A. The RMSPE would decrease, and the model would fit the data better.
# B. The RMSPE would decrease, and the model would fit the data just as well as before.
# C. The RMSPE would increase, and the model would fit the data just as well as before.
# D. The RMSPE would increase, and the model would fit the data worse.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 4**
# <br> {points: 4}
#
# A `confusionMatrix` for data with a predictive target with 2 different classes ("Positive" and "Negative") is shown below.
# i) Calculate the **accuracy** (Either by hand or using R. Show your calculation or your code).
# ii) Calculate the **precision** (Either by hand or using R. Show your calculation or your code).

# %%
##                    Truth
## Prediction    Positive Negative
##      Positive    17       3 
##      Negative     5      14

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 5**
# <br> {points: 1}
#
# The main difference between k-NN classification and k-NN regression is:
#
# A. the distance measure used
# B. how the neighbours are selected
# C. whether the output is numeric (regression) or categorical (classification)
# D. k-NN regression requires linearity

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 6**
# <br> {points: 1}
#
# In classification, the purpose of cross-validation is to…
#
# A. Maximize training accuracy
# B. Choose model with smallest training error
# C. Estimate how well model generalizes to new data
# D. Remove outliers

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 7**
# <br> {points: 1}
#
# Why do we usually scale numeric predictors before using k-NN?
#
# A. Make models faster
# B. Ensure variables contribute equally to distance
# C. Reduce training error
# D. k-NN can’t handle numeric predictors

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 8**
# <br> {points: 3}
#
# Suppose you just ran `tidymodels` cross-validation in KNN regression, and used `collect_metrics()` to
# summarise the results. The first line of the results object looks like this:

# %%
# A tibble: 1 × 7
  neighbors   .metric   .estimator   mean   n   std_err   .config
   <int>       <chr>      <chr>     <dbl> <int>  <dbl>      <chr>
1    1         rmse      standard    6.86   5    0.288  Preprocessor1_Model1
...

# %% [markdown]
# Now, you want to pick the best value of K based on RMSE. Fill in the code below to do this.
# *Hint: `best_k` should be a single numeric value, not a tibble or data frame.*
# **Do not try executing the code, as it will just generate an error message.**

# %%
# best_k <- metrics |>
#   filter(... == ...) |>
#   arrange(...) |>
#   slice(1) |>
#   ...(neighbors)

# your code here

# %% [markdown]
# **Question 9**
# <br> {points: 3}
#
# Suppose we ran a KNN regression model to predict the price of a house in Toronto. The table below contains 3 true house prices from the test set, along with the corresponding house price that the model predicted. All values are in hundreds of thousands of dollars.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:13px 10px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:13px 10px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg"><thead>
#   <tr>
#     <th class="tg-0lax" colspan="2"></th>
#   </tr></thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax" colspan="1">House price (test data)</td>
#     <td class="tg-0lax" colspan="1">House price (predicted)</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">512</td>
#     <td class="tg-0lax">650</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">709</td>
#     <td class="tg-0lax">720</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">922</td>
#     <td class="tg-0lax">1370</td>
#   </tr>
# </tbody></table>
#
# Compute the RMSPE (in hundreds of thousands of dollars) of the model based on this small test set. (If you use R to perform this calculation, include your code.)

# %% [markdown]
# ##### Answer:

# %% [markdown]
# -----

# %% [markdown]
# ### Palmer Penguins Data
#
# The `penguins` dataset has been loaded as part of the `palmerpenguins` package.
#
# `penguins` dataset
#
# **Description**
# Includes measurements for penguin species, island in Palmer Archipelago, size (flipper length, body mass, bill dimensions), and sex. This is a subset of penguins_raw.
#
# **Format**
# - `species`: a factor denoting penguin species (Adélie, Chinstrap and Gentoo)
# - `island`: a factor denoting island in Palmer Archipelago, Antarctica (Biscoe, Dream or Torgersen)
# - `bill_length_mm`: a number denoting bill length (millimeters)
# - `bill_depth_mm`: a number denoting bill depth (millimeters)
# - `flipper_length_mm`: an integer denoting flipper length (millimeters)
# - `body_mass_g`: an integer denoting body mass (grams)
# - `sex`: a factor denoting penguin sex (female, male)
# - `year`: an integer denoting the study year (2007, 2008, or 2009)

# %%
glimpse(penguins)

# %% [markdown]
# **Question 10**
# <br> {points: 4}
#
# Fill in the code below to randomly partition the `penguins` dataset into training (70%) and testing (30%) datasets, stratifying by the `species` variable.

# %%
set.seed(2025)
#penguins_split <- ...(..., ... = ..., ... = ...)
#penguins_train <- ...(penguins_split)
#penguins_test <- ...(penguins_split)

#your code here

# %% [markdown]
# **Question 11**
# <br> {points: 3}
#
# We wish to use KNN classification to classify penguin `species` using its `bill_length_mm` and `bill_depth_mm`.
# Fill in the code below to create a recipe for this classification task that also scales and centers all predictors, using the training dataset.

# %%
#knn_recipe <- ...(... ~ ..., ... = ...) |>
#    ...(all_predictors()) |>
#    ...(all_predictors())

#your code here

# %% [markdown]
# -----

# %% [markdown]
# ### Fuel economy data
#
# The `mpg` dataset has been loaded as part of the `ggplot2` package.. It contains fuel economy data from 1999 to 2008 for 38 popular models of cars.
#
# **Description**
# This dataset contains a subset of the fuel economy data that the EPA makes available on https://fueleconomy.gov/. It contains only models which had a new release every year between 1999 and 2008 - this was used as a proxy for the popularity of the car.
#
# `mpg` dataset
#
# **Format**
# - `manufacturer`: manufacturer name
# - `model`: model name
# - `displ`: engine displacement (size), in litres
# - `year`: year of manufacture
# - `cyl`: number of cylinders
# - `trans` type of transmission
# - `drv`: the type of drive train, where f = front-wheel drive, r = rear wheel drive, 4 = 4wd
# - `cty`: city miles per gallon
# - `hwy`: highway miles per gallon
# - `fl`: fuel type
# - `class`: "type" of car

# %%
glimpse(mpg)

# %% [markdown]
# **Question 12**
# <br> {points: 4}
#
# The code below fits a KNN model with K = 3 neighbors to predict a vehicle's miles per gallon in the city, `cty` using its engine size, `displ`.

# %%
#auto_recipe <- recipe(cty ~ displ, data = mpg) |>
#    step_center(all_predictors()) |>
#    step_scale(all_predictors())

#model_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 3) |>
#    set_engine("kknn") |>
#    set_mode("regression")

#workflow <- workflow() |>
#    add_recipe(auto_recipe) |>
#    add_model(model_spec) |>
#    fit(data = mpg)

# %% [markdown]
# Now, suppose you want to modify this code to:
# predict an vehicle's miles per gallon in the city, `cty` using its engine size, `displ`, and number of cylinders, `cyl` using a linear regression model instead of a KNN model.
#
# **Modify three lines of code from the code above in order to do this.**
#
# The original code is repeated below for modification.

# %%
auto_recipe <- recipe(cty ~ displ, data = mpg) |>
    step_normalize(all_predictors())

model_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 3) |>
    set_engine("kknn") |>
    set_mode("regression")

workflow <- workflow() |>
    add_recipe(auto_recipe) |>
    add_model(model_spec) |>
    fit(data = mpg)

# %% [markdown]
# -----

# %% [markdown]
# ##### When you have completed your work <br><br> - File > Save and Export Notebook As > PDF, or <br> - File > Print > Save as PDF <br> - Submit your pdf through Crowdmark

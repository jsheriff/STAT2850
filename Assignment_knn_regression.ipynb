# %% [markdown]
# # Assignment 6: k-NN Regression
#
# ### Objectives:
#
# * Use `tidyverse` to construct and fit a k-nearest neighbours model for regression.
# * Evaluate classification accuracy using a test data set and appropriate metrics.
# * Use cross validation to choose the number of neighbours.

# %%
###
### Run this cell before continuing.
###

library(repr)
library(tidyverse)
library(tidymodels)
options(repr.matrix.max.rows = 6)

# %% [markdown]
# ## 1. Bike-Sharing
#
# *Dataset and description courtesy of UC Irvine Machine Learning Repository.*
#
#
# Bike sharing systems are new generation of traditional bike rentals where the whole process from membership, rental and return back has become automatic. Through these systems, a user is able to easily rent a bike from a particular position and return it to another position. Currently, there are about over 500 bike-sharing programs around the world which is composed of over 500 thousands bicycles. Today, there exists great interest in these systems due to their important role in traffic, environmental and health issues.
#
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by these systems make them attractive for the research. As opposed to other transport services such as bus or subway, the duration of travel, departure and arrival position is explicitly recorded in these systems. This feature turns bike sharing system into a virtual sensor network that can be used for sensing mobility in the city. Hence, it is expected that most of important events in the city could be detected via monitoring these data.
#
# Today, we will be analyzing [data obtained from Capital Bikeshare](http://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset#), a bike-sharing system from Washington, DC. This dataset contains the hourly count of rental bikes between years 2011 and 2012 in Capital bikeshare system with the corresponding weather and seasonal information.

# %% [markdown]
# **Variables**
#
# - `instant`: &emsp; index
# - `dteday`: &emsp; Date
# - `season`: &emsp; 1: winter, 2: spring, 3: summer, 4: fall
# - `yr`:	&emsp;  year (0: 2011, 1: 2012)
# - `mnth`:	&emsp;  month (1 to 12)
# - `hr`:	&emsp;  hour (0 to 23)
# - `holiday`:	&emsp;  0: not a holiday, 1: holiday
# - `weekday`:	&emsp;  day of the week
# - `workingday`:	&emsp;  0: weekend or holiday, 1: workday
# - `weathersit`:	<br>&emsp;&emsp;&emsp;  1: Clear, Few clouds, Partly cloudy, Partly cloudy <br>
# 		&emsp;&emsp;&emsp;2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist<br>
# 		&emsp;&emsp;&emsp;3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds<br>
# 		&emsp;&emsp;&emsp;4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - `temp`:	&emsp;  Normalized temperature in Celsius
# - `atemp`:	&emsp;  Normalized feeling temperature in Celsius
# - `hum`:	&emsp;  Normalized humidity
# - `windspeed`:	&emsp;  Normalized wind speed
# - `casual`:	&emsp;  count of casual users
# - `registered`:	&emsp;  count of registered users
# - `cnt`:	&emsp;  count of total rental bikes including both casual and registered

# %% [markdown]
# **Question 1.1**
# <br> {points: 1}
#
# Since we already have `tidyverse` loaded and ready to use, the first step is to read our new data, `bike_hour.csv`. Make sure to assign your answer to `bike_data`. The data regard the bike sharing counts aggregated on hourly basis.

# %%
# your code here


bike_data

# %% [markdown]
# **Question 1.2**
# <br> {points: 1}
#
# How many observations and variables are in this dataset?

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 1.3**
# <br> {points: 1}
#
# We are particularly interested in the following quantitative variables:
#
# - `atemp`: normalized feeling temperature in Celsius
# - `hum`: normalized humidity
# - `windspeed`: normalized wind speed
# - `cnt`: count of total rental bikes (response variable)
#
# Select these columns from the dataset. Name this new dataset `bike_select`.

# %%
#... <- select(...)

# your code here


bike_select

# %% [markdown]
# **Question 1.4**
# <br> {points: 2}
#
# **Before** we perform exploratory data analysis, we should create our training and testing data sets. First, split the `bike_select` data set. Use 80% of the data for the training dataset and set the variable we want to predict as the `strata` argument. Assign your answer to an object called `bike_split`.
#
# Assign your training data set to an object called `bike_training` and your testing data set to an object called `bike_testing`.

# %%
set.seed(2112)

#... <- initial_split(..., prop = ..., strata = ...)
#... <- training(...)
#... <- testing(...)

# your code here

# %% [markdown]
# **Question 1.5**
# <br> {points: 2}
#
# Using `ggplot` and `bike_training` create a histogram of the response varibale, `cnt`. Use bin size of 10 and color of your choice to fill the bars.

# %%
# your code here

# %% [markdown]
# **Question 1.6**
# <br> {points: 3}
#
# Since the number of bike rentals is strongly influenced by weather conditions, create a scatterplot using `ggplot` with `atemp` (normalized feeling temperature in Celsius) on the x-axis and `windspeed`(normalized wind speed) on the y-axis. To visualize the relationship between these weather conditions and bike rentals, `cnt` (count of rentals), use `color` to represent `cnt` values. Add `scale_colour_gradientn(colours = rev(hcl.colors(12)))` as the last layer for your plot to specify a scale color from yellow to dark blue with 12 levels.
#
# *Don't forget to label your axes! Where appropriate, axes labels should also include units (for example, the axis mapped to the `temperature` column should have the units "normalized degrees Celsius").*

# %%
# your code here

# %% [markdown]
# **Question 1.7**
# <br> {points: 2}
#
# In one or two sentences, what does the scatterplot suggest about the relationship between the number of bike rentals, `cnt`, and temperature, `atemp`.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 1.8**
# <br> {points: 2}
#
# Create a `tidymodels` recipe to *standardize* (i.e., center and scale) all of the variables in the `bike_training` dataset.
#
# Specify your recipe with response variable `cnt` and predictors `atemp`, `hum`, and `windspeed`.
#
# Name the recipe `bike_recipe`.

# %%
# your code here


bike_recipe

# %% [markdown]
# **Question 1.9**
# <br> {points: 2}
#
# Create the K-nearest neighbour model specification. Specify we want 5 nearest neighbors. Name this model specification as `bike_spec`.

# %%
# your code here

bike_spec

# %% [markdown]
# **Question 1.10**
# <br> {points: 2}
#
# Now that we have our model specification and recipe, let's put them together in a workflow, and fit our kNN regression model. Assign the fit to an object called `bike_fit`.

# %%
# your code here

bike_fit

# %% [markdown]
# **Question 1.11**
# <br> {points: 3}
#
# Now use the fitted model to make prediction on test data. Calculate the RMSE
#  to assess goodness of fit on `bike_fit` (this is how well it predicts on the **training** data used to fit the model). Return a single numerical value named `lm_rmse`.

# %%
#... <- bike_fit %>%
#         predict(...) %>%
#         bind_cols(...) %>%
#         ...(truth = ..., estimate = ...) %>%
#         filter(.metric == ...) %>%
#         select(...) %>%
#         pull()

# your code here

lm_rmse

# %% [markdown]
# **Question 1.12**
# <br> {points: 2}
#
# Calculate $RMSPE$ using the test data. Return a single numerical value named `lm_rmspe`.

# %%
# your code here

lm_rmspe

# %% [markdown]
# **Question 1.13**
# <br> {points: 5}
#
# Now use cross validation to find the best *k*.
#
# - Create the splits for cross-validation with *5 folds* using the `vfold_cv` function.
# - Create a tibble including the range of K's that that goes from 1 to 201 by jumps of 20.
# - Create a recipe that uses `atemp`, `hum`, and `windspeed` and a model specification with tuning on the number of neighbours
# - Create a workflow analysis with your recipe and model specification and tune your workflow such that it tests all the values of $K$ and resamples using your cross-validation data set
# - Collect the metrics from the workflow analysis. Assign your answer to an object called `bike_results`

# %%
set.seed(2112)

# your code here

bike_results

# %% [markdown]
# **Question 1.14**
# <br> {points: 3}
#
# Using `bike_results`, plot the $k$ vs the `rmse`. Assign this plot to an object called `cross_val_plot`

# %%
# your code here

cross_val_plot

# %% [markdown]
# **Question 1.15**
# <br> {points: 2}
#
# Based on the results from **Question 1.13** and the plot from **Question 1.14**, which $k$ would you choose and why?

# %% [markdown]
# #### Answer:

# %% [markdown]
# ## Let's build our final model
#
# **Question 1.16**
# <br> {points: 3}
#
# Now that we have explored our data, separated the data into training and testing sets, and applied cross-validation to choose the best $k$, we can build our final model.
#
# First, build your model specification with the best value for $K$ that you selected. Assign your answer to an object called `bike_final_spec`.
#
# Then, pass the model specification and the training data set to the `fit()` function. Assign your answer to an object called `bike_final_fit`.

# %%
# your code here

bike_final_fit

# %% [markdown]
# **Question 1.17**
# <br> {points: 2}
#
# Use your final model to predict on the test dataset and assign this to an object called `bike_final_predictions`. Collect the metrics for this prediction, and store this in an object named `bike_final_metrics`.

# %%
# your code here

bike_final_metrics

# %% [markdown]
# **Question 1.18**
# <br> {points: 2}
#
# In one or two sentences discuss what the prediction results tell us about the usefulness of our model in predicting bike rentals.

# %% [markdown]
# ##### Answer:

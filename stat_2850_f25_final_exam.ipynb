# %% [markdown]
# # STAT 2580 - Introduction to Data Science
# # Final Exam
#
# -------
# ### Instructions:
# - Answer **all** questions in the spaces provided.
# - Do **not** delete or modify question text.
# - You may add code cells or markdown cells as necessary
# - Use **R** as necessary.
# - Show your work where possible and include brief explanations when asked.
# - Exam is open book.
# - You must complete the exam on your own.

# %%
### Run this cell before continuing. 
library(repr)
library(tidyverse)
library(tidymodels)
library(palmerpenguins)
options(repr.matrix.max.rows = 6) #limits output of dataframes to 6 rows

# %% [markdown]
# **Question 1**
# <br> {points: 1}
#
# **True/False:** Data wrangling is generally the least time-consuming step in a typical data science project.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 2**
# <br> {points: 3}
#
# **Instructions:** Match the term in Column A with its best description in Column B. Write the corresponding letter next to the number.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-lboi{border-color:inherit;text-align:left;vertical-align:middle}
# .tg .tg-g7sd{border-color:inherit;font-weight:bold;text-align:left;vertical-align:middle}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg"><thead>
#   <tr>
#     <th class="tg-g7sd">Column A (Term)</th>
#     <th class="tg-g7sd">Column B (Description)</th>
#   </tr></thead>
# <tbody>
#   <tr>
#     <td class="tg-lboi">1. geom_bar()</td>
#     <td class="tg-lboi">A. Visualizes the distribution of a continuous variable across categories.</td>
#   </tr>
#   <tr>
#     <td class="tg-lboi">2. geom_line()</td>
#     <td class="tg-lboi">B. Creates multiple sub-plots based on a categorical variable..</td>
#   </tr>
#   <tr>
#     <td class="tg-lboi">3. facet_wrap()</td>
#     <td class="tg-lboi">C. Used to map a variable to the color of points or lines.</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">4. geom_boxplot()</td>
#     <td class="tg-0lax">D. Best for showing trends over time.</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">5. aes(color = ...)</td>
#     <td class="tg-0lax">E. Used for representing counts of categorical data.</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 3**
# <br> {points: 3}
#
# Briefly describe the three rules that define a dataset as "tidy."

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 4**
# <br> {points: 1}
#
# When is **dropping missing values** generally preferable to **imputing** them?
#
# A. When missingness is extensive
# B. When missingness is systematic
# C. When only a small fraction of values are missing at random
# D. When prediction accuracy is the only goal

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 5**
# <br> {points: 1}
#
# Which statement about reproducible data science is **most accurate**?
#
# A. Reproducibility requires large datasets
# B. Reproducibility means results never change
# C. Code + data + narrative allow results to be recreated
# D. Reproducibility only applies to statistical inference

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 6**
# <br> {points: 1}
#
# In `ggplot()`, what is the difference between *mapping* an aesthetic and *setting* an aesthetic?
#
# A. Mapping uses `=`; setting uses `<-`
# B. Mapping varies by data; setting applies a constant value
# C. Mapping applies only to color
# D. There is no difference

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 7**
# <br> {points: 1}
#
# Which tidyverse function is most appropriate for creating a new variable based on existing columns?
#
# A. `select()`
# B. `mutate()`
# C. `summarize()`
# D. `filter()`

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 8**
# <br> {points: 1}
#
# Which of the following is a "classification" task?
#
# A. Predicting the price of a house.
# B. Predicting the temperature for tomorrow.
# C. Predicting whether a bank transaction is "Fraudulent" or "Legitimate."
# D. Predicting the number of students who will pass an exam.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 9**
# <br> {points: 1}
#
# **True/False:** $k$-Nearest Neighbors ($k$-NN) is a non-parametric model, meaning it makes strong assumptions about the functional form of the relationship between variables.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 10**
# <br> {points: 1}
#
# Which workflow best reflects tidymodels?
#
# A. Clean → plot → fit → deploy
# B. Split → preprocess → specify model → fit → evaluate
# C. Import → cluster → regress
# D. Visualize → bootstrap → test

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 11**
# <br> {points: 1}
#
# You have a confusion matrix where:
# - True Positives (TP) = 80
# - False Positives (FP) = 10
# - False Negatives (FN) = 10
# - True Negatives (TN) = 100
#
# What is the **Precision** of this model?
#
# A. $180 / 200$
# B. $80 / 100$
# C. $80 / 90$
# D. $10 / 80$

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 12**
# <br> {points: 1}
#
# **True/False:** In the context of the training-test split, the test set is used to tune the model's hyperparameters (like the $k$ in $k$-NN).

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 13**
# <br> {points: 1}
#
# In a simple linear regression model $Y = \beta_0 + \beta_1 X + \epsilon$, what does the $R^2$ value represent?
#
# A. The slope of the regression line.
# B. The average error of the predictions.
# C. The proportion of the variance in the response variable that is explained by the explanatory variable.
# D. The probability that the null hypothesis is true.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 14**
# <br> {points: 1}
#
# A digit-classification model (classifying hand-written numbers) has accuracy 0.74. Is this “good”?
#
# A. Always yes
# B. Always no
# C. It depends on context and consequences of errors
# D. Only if data are balanced

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 15**
# <br> {points: 3}
#
# Briefly explain why one should not extrapolate when using a k-NN regression model.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 16**
# <br> {points: 1}
#
# Which metric is most appropriate for evaluating a classification model with multiple classes?
#
# A. RMSE
# B. Accuracy
# C. $R^2$
# D. MAE

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 17**
# <br> {points: 1}
#
# What happens when k is very small in k-NN classification?
#
# A. High bias
# B. Underfitting
# C. High variance
# D. Low flexibility

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 18**
# <br> {points: 1}
#
# In estimation, the purpose of the bootstrap distribution is to approximate the spread of...
#
# A. the population distribution
# B. the sampling distribution
# C. the normal distribution
# D. the distribution of the sample

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 19**
# <br> {points: 1}
#
# Suppose we collected information about the amount of water that students drink per day from every single University of Lethbridge student. We found that the true mean of this population is 1.98 litres.
# Which statement listed below is **not** correct?
#
# A. The bootstrap distribution of bootstrapped means (from a single random sample) will always be centered at 1.98
# B. The bootstrap distribution of bootstrapped means (from a single random sample) will be centered at the mean of the original sample from which those bootstrap samples were taken
# C. The sampling distribution of sample means and the bootstrap distribution of bootstrapped means do not necessarily have the same center
# D. The sampling distribution for sample means should be centered at around 1.98
# E. The spread of the sampling distribution for sample means, and the bootstrap distribution of bootstrapped means (from a single random sample) should be proportional to the sample size.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 20**
# <br> {points: 1}
#
# In which of the following questions would inferential methods (e.g., estimation or hypothesis testing) be appropriate?
#
# A. What variables are useful for predicting the amount of time a university student spends on social media in a day?
# B. From a small dataset of university students from University of Lethbridge, what proportion of them use social media for more than 2 hoursper day?
# C. What proportion of university students at University of Lethbridge use social media for more than 2 hours per day?
# D. None of the above are inferential questions.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 21**
# <br> {points: 1}
#
# Which of the following is a correct statement about the relationship between the spread of a sampling distribution and the sample size.
#
# A. The center of the sampling distribution increases when the sample size increases.
# B. The center of the sampling distribution decreases when the sample size increases.
# C. The spread of the sampling distribution increases when the sample size increases.
# D. The spread of the sampling distribution decreases when the sample size increases.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 22**
# <br> {points: 2}
#
# **Instructions:** Match the term in Column A with its best description in Column B. Write the corresponding letter next to the number.
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-lboi{border-color:inherit;text-align:left;vertical-align:middle}
# .tg .tg-g7sd{border-color:inherit;font-weight:bold;text-align:left;vertical-align:middle}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg"><thead>
#   <tr>
#     <th class="tg-g7sd">Column A (Term)</th>
#     <th class="tg-g7sd">Column B (Description)</th>
#   </tr></thead>
# <tbody>
#   <tr>
#     <td class="tg-lboi">1. Overfitting</td>
#     <td class="tg-lboi">A. A technique used to estimate the variability of a statistic by repeatedly drawing samples with replacement from the original sample data.</td>
#   </tr>
#   <tr>
#     <td class="tg-lboi">2. Bias</td>
#     <td class="tg-lboi">B. A model that performs very well on the training data but poorly on unseen test data.</td>
#   </tr>
#   <tr>
#     <td class="tg-lboi">3. Variance</td>
#     <td class="tg-lboi">C. A measure of how much a model's prediction changes when the training data is changed slightly.</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">4. Bootstrap</td>
#     <td class="tg-0lax">D. The tendency of a model to consistently learn the wrong relationship between features and the target.</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 23**
# <br> {points: 1}
#
# Which statement best distinguishes clustering from classification?
#
# A. Clustering predicts numeric outcomes
# B. Classification does not use predictors
# C. Clustering has no response variable
# D. Classification uses distance metrics

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 24**
# <br> {points: 1}
#
# A 95% bootstrap confidence interval means:
#
# A. There is a 95% chance the parameter is inside
# B. 95% of the data lie in the interval
# C. 95% of such intervals capture the true parameter
# D. The parameter varies randomly

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 25**
# <br> {points: 1}
#
# What is *sampling variability*?
#
# A. Error due to measurement
# B. Natural variation between samples
# C. Bias in estimators
# D. Model misspecification

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 26**
# <br> {points: 1}
#
# What is the primary goal of bootstrapping?
#
# A. Hypothesis testing
# B. Parameter estimation under a null
# C. Estimating uncertainty
# D. Classification accuracy

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 27**
# <br> {points: 1}
#
# Clustering is considered:
#
# A. Supervised learning
# B. Semi-supervised learning
# C. Unsupervised learning
# D. Reinforcement learning

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 28**
# <br> {points: 1}
#
# In K-means clustering, how is the "Total Within-Cluster Sum of Square Deviations" (WSSD) used to find the optimal number of clusters?
#
# A. We look for the "elbow" where WSSD starts to decrease rapidly.
# B. We look for the "elbow" where the rate of decrease in WSSD slows down significantly.
# C. We choose the value of K where WSSD is at its absolute maximum.
# D. WSSD is not used for determining the number of clusters.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# **Question 29**
# <br> {points: 3}
#
# Briefly explain why multiple starts are used in the `k-means` procedure.

# %% [markdown]
# ##### Answer:

# %% [markdown]
# -----

# %% [markdown]
# ### Palmer Penguins Data
#
# The `penguins` dataset has been loaded as part of the `palmerpenguins` package.
#
# `penguins` dataset
#
# **Description**
# Includes measurements for penguin species, island in Palmer Archipelago, size (flipper length, body mass, bill dimensions), and sex. This is a subset of `penguins_raw`.
#
# **Format**
# - `species`: a factor denoting penguin species (Adélie, Chinstrap and Gentoo)
# - `island`: a factor denoting island in Palmer Archipelago, Antarctica (Biscoe, Dream or Torgersen)
# - `bill_length_mm`: a number denoting bill length (millimeters)
# - `bill_depth_mm`: a number denoting bill depth (millimeters)
# - `flipper_length_mm`: an integer denoting flipper length (millimeters)
# - `body_mass_g`: an integer denoting body mass (grams)
# - `sex`: a factor denoting penguin sex (female, male)
# - `year`: an integer denoting the study year (2007, 2008, or 2009)

# %%
head(penguins)

# %% [markdown]
# **Question 30**
# <br> {points: 4}
#
# The code below currently generates a plot of counts of the number of penguins on each island.
#
# Modify the code so that the plot displays the proportion of each penguin species on each island.

# %%
#original code
ggplot(data = penguins, aes(x = island)) +
    geom_bar() +
    labs(x = "Island", y = "Proportion")

# %%
#your code here

# %% [markdown]
# -----

# %% [markdown]
# ### Mammals sleep data
#
# The `msleep` (mammals sleep) data set contains the sleep times and weights for a set of mammals. This data set contains 83 rows and 11 variables. The `msleep` dataset has been loaded as part of the `ggplot2` package.
#
# `msleep` dataset
#
# **Format**
# - `name`:	common name
# - `genus`:	taxonomic rank
# - `vore`(diet):	carnivore, omnivore or herbivore?
# - `order`:	taxonomic rank
# - `conservation`:	the conservation status of the mammal
# - `sleep_total`:	total amount of sleep, in hours
# - `sleep_rem`:	rem sleep, in hours
# - `sleep_cycle`:	length of sleep cycle, in hours
# - `awake`:	amount of time spent awake, in hours
# - `brainwt`:	brain weight in kilograms
# - `bodywt`:	body weight in kilograms

# %%
head(msleep)

# %% [markdown]
# **Question 31**
# <br> {points: 4}
#
# Using the tidyverse, write code that performs the following on the `msleep` dataset:
#
# 1. Filter the data for animals that are "herbi" (herbivores).
# 2. Create a new column `sleep_total_min` which is `sleep_total` multiplied by 60.
# 3. Select only the `name`, `order`, and `sleep_total_min` columns.
# 4. Sort the result by `sleep_total_min` in descending order.

# %%
# your code here

# %% [markdown]
# **Question 32**
# <br> {points: 3}
#
# Create and display a scatterplot of `sleep_total` vs. the log of `bodywt`, `log(bodywt)`, and colour the points by diet, `vore`. Place total sleep on the y-axis. Be sure to include meaningful labels.

# %%
# your code here

# %% [markdown]
# -----

# %% [markdown]
# ### Tree data
#
# The `trees` dataset provides measurements of the diameter, `Height` and `Volume` of timber in 31 felled black cherry trees. Note that the diameter (in inches) is erroneously labelled `Girth` in the data. It is measured at 4 ft 6 in above the ground.
#
# A data frame with 31 observations on 3 variables.
#
# `trees` dataset
#
# **Format**
# - `Girth`:	Tree diameter (rather than girth, actually) in inches
# - `Height`:	Height in ft
# - `Volume`:	Volume of timber in cubic ft

# %%
head(trees)

# %% [markdown]
# **Question 33**
# <br> {points: 4}
#
# Consider the `trees` dataset in R:

# %% [markdown]
# Complete the code below to create a K-means clustering model with K = 4 clusters, 10 restarts.
#
# **DO NOT RUN THE CODE**

# %%
#library(tidyverse)
#library(tidymodels)
#library(...)

#tree_recipe <- recipe(..., data = trees) |>
#    step_scale(all_predictors()) |>
#    step_center(all_predictors())

#tree_spec <- k_means(...) 
#        |> set_engine(..., ...)

#your code here

# %% [markdown]
# **Question 34**
# <br> {points: 4}
#
# Consider the `trees` dataset in R.

# %% [markdown]
# Suppose you have already run `k_means` with 4 clusters and 10 restarts, and suppose the output of `k_means` fitting is stored in a variable called `trees_fit`.
#
# Complete the code below to visualize the clustering results in a coloured scatterplot. The
# `Height` variable should be on the y-axis and the `Girth` variable on the x-axis.
#
# **DO NOT RUN THE CODE**

# %%
#labelled_trees <- trees_fit |> augment(trees)
#ggplot(..., aes(x = ..., y = ..., color = ...)) +
# ...()

#your code here

# %% [markdown]
# **Question 35**
# <br> {points: 4}
#
# Consider the `trees` dataset.

# %% [markdown]
# Fill in the code below to take 1000 bootstrap samples from the `trees` dataset. Each bootstrap sample should be the same size as the original `trees` sample.
#
# *Hint: the `nrow` function takes a tibble as an argument and returns the number of rows in that tibble.*
#
# **YOU ARE NOT REQUIRED TO RUN THE CODE**

# %%
#trees_boot1000 <- trees |>
#    ...(... = nrow(...), ... = TRUE, reps = 1000)

#your code here

# %% [markdown]
# **Question 36**
# <br> {points: 2}
#
# Consider the `trees` dataset.
#
# Suppose we took 1000 bootstrap samples, each of size 31, and computed the mean timber volume for each bootstrap sample. Suppose those means are stored in a tibble called `trees_boot1000_means`, and the first few lines of it are shown below.

# %%
#head(trees_boot1000_means)

# %%
# A tibble: 6 × 2
#    replicate  mean
#        <int> <dbl>
#1           1  29.1
#2           2  26.4 
#3           3  28.0
#4           4  28.8
#5           5  33.4
#6           6  35.0

# %% [markdown]
# Fill in the code below to calculate an approximate 90% bootstrap confidence interval based on these 1000 bootstrap sample means.
#
# *Hint: the two values in quantile should be the upper and lower percentiles such that 5% of observations fall below the range, and 5% of observations are above the range. The values should be in decimal format, not percentage format (example: 0.02 rather 2%).*
#
# **DO NOT RUN CODE**

# %%
#trees_boot1000_means |>
#        pull(mean) |>
#        quantile(c(..., ...))

#your code here

# %% [markdown]
# **Question 37**
# <br> {points: 8}
#
# Consider the `trees` dataset.
#
# Using the `tidymodels` framework:
#
# 1. Create a 70/30 split for training and testing.
# 2. Build a recipe that predicts `Volume` using `Girth` and `Height`. Do not normalize (scale and centre) the data.
# 3. Specify a linear regression model.
# 4. Fit the linear regression model using the training data
# 5. Use the fitted model to predict `Volume` for the test set.
# 6. Calculate and report the RMSE (Root Mean Squared Error) on the test set, which is often referred to as the RMSPE (Root Mean Squared Prediction Error).

# %%
#your code here

# %% [markdown]
# ##### Answer:

# %% [markdown]
# -----

# %% [markdown]
# ##### When you have completed your work <br><br> - File > Save and Export Notebook As > PDF, or <br> - File > Print > Save as PDF <br> - Submit your pdf through Crowdmark
